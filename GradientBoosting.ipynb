# %%
# import usual libraries for machine learing and data science
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

file_list = os.listdir("Dataset")
file_list = [file.replace(".csv", "") for file in file_list]

# put file names in file_list that have world splitTrain to file_list_train
file_list_train = [file for file in file_list if "splitTrain" in file]
file_list_test = [file for file in file_list if "splitTest" in file]

data_train = {}
for file in file_list_train:
    data_train[file.replace("splitTrain_", "").replace("splitTrain", "")] = pd.read_csv("Dataset/" + file + ".csv")

data_test = {}
for file in file_list_test:
    data_test[file.replace("splitTest_", "").replace("splitTest", "")] = pd.read_csv("Dataset/" + file + ".csv")

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, roc_auc_score, precision_score, recall_score

def get_ada_score(data_train, data_test):
  performance_score = {}
  for key in data_train:
    try:
      X_train = data_train[key].drop(["HeartDisease"], axis=1)
      y_train = data_train[key]["HeartDisease"]
      X_test = data_test[key].drop(["HeartDisease"], axis=1)
      y_test = data_test[key]["HeartDisease"]

      abc = AdaBoostClassifier(n_estimators=500, learning_rate=0.01, random_state=0)
      model = abc.fit(X_train, y_train)
      y_pred = model.predict(X_test)

      performance_score[key] = {'f1_score' : f1_score(y_test, y_pred)}
      performance_score[key]['accuracy'] = accuracy_score(y_test, y_pred)
      performance_score[key]['confusion_matrix'] = confusion_matrix(y_test, y_pred)
      performance_score[key]['roc_auc_score'] = roc_auc_score(y_test, y_pred)
      performance_score[key]['precision_score'] = precision_score(y_test, y_pred)
      performance_score[key]['recall_score'] = recall_score(y_test, y_pred)
    except:
      continue
  return performance_score

from sklearn.model_selection import KFold, cross_val_score

# function to cross validate the model using KFold
def cross_validate_ada(data_train, model):
    performanceData = {}
    for key in data_train:
      try:
        X_train = data_train[key].drop(["HeartDisease"], axis=1)
        y_train = data_train[key]["HeartDisease"]

        kf = KFold(n_splits=10, shuffle=True)
        scores = cross_val_score(model(n_estimators=500, learning_rate=0.01, random_state=0), X_train, y_train, cv=kf, scoring="f1_macro")
        performanceData[key] = scores.mean()
      except:
        continue
            
    return performanceData

# %%
ada_score = get_ada_score(data_train, data_test)

# %%
df_ada_score = pd.DataFrame.from_dict(ada_score, orient='index')
df_ada_score.sort_values(by=["f1_score", "accuracy"], ascending=[False, False], inplace=True)
df_ada_score
# Out:
#                                             f1_score  accuracy  \
# df_encoded_                                 0.873874  0.847826
# df_DF_encoded_                              0.847926  0.820652
# df_DF_modifiedOutlier_encoded_minmaxScaled  0.817518  0.829932
# df_deleteOutlier_encoded_minmaxScaled       0.812030  0.822695
# df_modifiedOutlier_encoded_                 0.808824  0.823129
# df_deleteOutlier_encoded_                   0.808824  0.815603
# df_DF_deleteOutlier_encoded_minmaxScaled    0.802920  0.808511
# df_modifiedOutlier_encoded_minmaxScaled     0.802920  0.816327
# df_DF_deleteOutlier_encoded_                0.800000  0.808511
# df_DF_modifiedOutlier_encoded_              0.785185  0.802721
# df_encoded_minmaxScaled                     0.770833  0.760870
# df_DF_encoded_minmaxScaled                  0.713514  0.711957
#
#                                                 confusion_matrix  \
# df_encoded_                                 [[59, 18], [10, 97]]
# df_DF_encoded_                              [[59, 18], [15, 92]]
# df_DF_modifiedOutlier_encoded_minmaxScaled   [[66, 9], [16, 56]]
# df_deleteOutlier_encoded_minmaxScaled       [[62, 12], [13, 54]]
# df_modifiedOutlier_encoded_                  [[66, 9], [17, 55]]
# df_deleteOutlier_encoded_                   [[60, 14], [12, 55]]
# df_DF_deleteOutlier_encoded_minmaxScaled    [[59, 15], [12, 55]]
# df_modifiedOutlier_encoded_minmaxScaled     [[65, 10], [17, 55]]
# df_DF_deleteOutlier_encoded_                [[60, 14], [13, 54]]
# df_DF_modifiedOutlier_encoded_              [[65, 10], [19, 53]]
# df_encoded_minmaxScaled                     [[66, 11], [33, 74]]
# df_DF_encoded_minmaxScaled                  [[65, 12], [41, 66]]
#
#                                             roc_auc_score  precision_score  \
# df_encoded_                                      0.836388         0.843478
# df_DF_encoded_                                   0.813023         0.836364
# df_DF_modifiedOutlier_encoded_minmaxScaled       0.828889         0.861538
# df_deleteOutlier_encoded_minmaxScaled            0.821904         0.818182
# df_modifiedOutlier_encoded_                      0.821944         0.859375
# df_deleteOutlier_encoded_                        0.815853         0.797101
# df_DF_deleteOutlier_encoded_minmaxScaled         0.809096         0.785714
# df_modifiedOutlier_encoded_minmaxScaled          0.815278         0.846154
# df_DF_deleteOutlier_encoded_                     0.808390         0.794118
# df_DF_modifiedOutlier_encoded_                   0.801389         0.841270
# df_encoded_minmaxScaled                          0.774366         0.870588
# df_DF_encoded_minmaxScaled                       0.730489         0.846154
#
#                                             recall_score
# df_encoded_                                     0.906542
# df_DF_encoded_                                  0.859813
# df_DF_modifiedOutlier_encoded_minmaxScaled      0.777778
# df_deleteOutlier_encoded_minmaxScaled           0.805970
# df_modifiedOutlier_encoded_                     0.763889
# df_deleteOutlier_encoded_                       0.820896
# df_DF_deleteOutlier_encoded_minmaxScaled        0.820896
# df_modifiedOutlier_encoded_minmaxScaled         0.763889
# df_DF_deleteOutlier_encoded_                    0.805970
# df_DF_modifiedOutlier_encoded_                  0.736111
# df_encoded_minmaxScaled                         0.691589
# df_DF_encoded_minmaxScaled                      0.616822

# %%
cross_val_ada = cross_validate_ada(data_train, AdaBoostClassifier)

# %%
df_cross_val_ada = pd.DataFrame.from_dict(cross_val_ada, orient='index')
df_cross_val_ada.rename(columns={0: "f1_score"}, inplace=True)
df_cross_val_ada.sort_values(by=["f1_score"], ascending=[False], inplace=True)
df_cross_val_ada
# Out:
#                                             f1_score
# df_encoded_minmaxScaled                     0.867755
# df_encoded_                                 0.863994
# df_DF_encoded_stdScaled_rounded             0.851468
# df_DF_deleteOutlier_encoded_minmaxScaled    0.847696
# df_modifiedOutlier_encoded_                 0.847517
# df_deleteOutlier_encoded_                   0.847195
# df_DF_encoded_                              0.847111
# df_DF_deleteOutlier_encoded_                0.844089
# df_deleteOutlier_encoded_minmaxScaled       0.841844
# df_modifiedOutlier_encoded_minmaxScaled     0.841703
# df_DF_encoded_minmaxScaled                  0.833220
# df_DF_modifiedOutlier_encoded_              0.829992
# df_DF_modifiedOutlier_encoded_minmaxScaled  0.820225

# %% [markdown]
# # XG Boost

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, roc_auc_score, precision_score, recall_score

def get_xg_score(data_train, data_test):
  performance_score = {}
  for key in data_train:
    try:
      X_train = data_train[key].drop(["HeartDisease"], axis=1)
      y_train = data_train[key]["HeartDisease"]
      X_test = data_test[key].drop(["HeartDisease"], axis=1)
      y_test = data_test[key]["HeartDisease"]

      abc = GradientBoostingClassifier(n_estimators=500, learning_rate=0.01, random_state=0)
      model = abc.fit(X_train, y_train)
      y_pred = model.predict(X_test)

      performance_score[key] = {'f1_score' : f1_score(y_test, y_pred)}
      performance_score[key]['accuracy'] = accuracy_score(y_test, y_pred)
      performance_score[key]['confusion_matrix'] = confusion_matrix(y_test, y_pred)
      performance_score[key]['roc_auc_score'] = roc_auc_score(y_test, y_pred)
      performance_score[key]['precision_score'] = precision_score(y_test, y_pred)
      performance_score[key]['recall_score'] = recall_score(y_test, y_pred)
    except:
      continue
  return performance_score

from sklearn.model_selection import KFold, cross_val_score

# function to cross validate the model using KFold
def cross_validate_xg(data_train):
    performanceData = {}
    for key in data_train:
      try:
        X_train = data_train[key].drop(["HeartDisease"], axis=1)
        y_train = data_train[key]["HeartDisease"]

        kf = KFold(n_splits=10, shuffle=True)
        scores = cross_val_score(GradientBoostingClassifier(n_estimators=500, learning_rate=0.01, random_state=0), X_train, y_train, cv=kf, scoring="f1_macro")
        performanceData[key] = scores.mean()
      except:
        continue
            
    return performanceData

# %%
xg_score = get_xg_score(data_train, data_test)

# %%
df_xg_score = pd.DataFrame.from_dict(xg_score, orient='index')
df_xg_score.sort_values(by=["f1_score", "accuracy"], ascending=[False, False], inplace=True)
df_xg_score
# Out:
#                                             f1_score  accuracy  \
# df_encoded_                                 0.871560  0.847826
# df_DF_encoded_                              0.866359  0.842391
# df_deleteOutlier_encoded_                   0.857143  0.865248
# df_DF_deleteOutlier_encoded_                0.846715  0.851064
# df_deleteOutlier_encoded_minmaxScaled       0.844444  0.851064
# df_modifiedOutlier_encoded_                 0.841379  0.843537
# df_DF_deleteOutlier_encoded_minmaxScaled    0.829630  0.836879
# df_DF_modifiedOutlier_encoded_minmaxScaled  0.825175  0.829932
# df_DF_modifiedOutlier_encoded_              0.817518  0.829932
# df_modifiedOutlier_encoded_minmaxScaled     0.816901  0.823129
# df_DF_encoded_minmaxScaled                  0.578313  0.619565
# df_encoded_minmaxScaled                     0.571429  0.608696
#
#                                                 confusion_matrix  \
# df_encoded_                                 [[61, 16], [12, 95]]
# df_DF_encoded_                              [[61, 16], [13, 94]]
# df_deleteOutlier_encoded_                    [[65, 9], [10, 57]]
# df_DF_deleteOutlier_encoded_                 [[62, 12], [9, 58]]
# df_deleteOutlier_encoded_minmaxScaled       [[63, 11], [10, 57]]
# df_modifiedOutlier_encoded_                 [[63, 12], [11, 61]]
# df_DF_deleteOutlier_encoded_minmaxScaled    [[62, 12], [11, 56]]
# df_DF_modifiedOutlier_encoded_minmaxScaled  [[63, 12], [13, 59]]
# df_DF_modifiedOutlier_encoded_               [[66, 9], [16, 56]]
# df_modifiedOutlier_encoded_minmaxScaled     [[63, 12], [14, 58]]
# df_DF_encoded_minmaxScaled                  [[66, 11], [59, 48]]
# df_encoded_minmaxScaled                     [[64, 13], [59, 48]]
#
#                                             roc_auc_score  precision_score  \
# df_encoded_                                      0.840029         0.855856
# df_DF_encoded_                                   0.835356         0.854545
# df_deleteOutlier_encoded_                        0.864562         0.863636
# df_DF_deleteOutlier_encoded_                     0.851755         0.828571
# df_deleteOutlier_encoded_minmaxScaled            0.851049         0.838235
# df_modifiedOutlier_encoded_                      0.843611         0.835616
# df_DF_deleteOutlier_encoded_minmaxScaled         0.836829         0.823529
# df_DF_modifiedOutlier_encoded_minmaxScaled       0.829722         0.830986
# df_DF_modifiedOutlier_encoded_                   0.828889         0.861538
# df_modifiedOutlier_encoded_minmaxScaled          0.822778         0.828571
# df_DF_encoded_minmaxScaled                       0.652870         0.813559
# df_encoded_minmaxScaled                          0.639883         0.786885
#
#                                             recall_score
# df_encoded_                                     0.887850
# df_DF_encoded_                                  0.878505
# df_deleteOutlier_encoded_                       0.850746
# df_DF_deleteOutlier_encoded_                    0.865672
# df_deleteOutlier_encoded_minmaxScaled           0.850746
# df_modifiedOutlier_encoded_                     0.847222
# df_DF_deleteOutlier_encoded_minmaxScaled        0.835821
# df_DF_modifiedOutlier_encoded_minmaxScaled      0.819444
# df_DF_modifiedOutlier_encoded_                  0.777778
# df_modifiedOutlier_encoded_minmaxScaled         0.805556
# df_DF_encoded_minmaxScaled                      0.448598
# df_encoded_minmaxScaled                         0.448598

# %%
cross_val_xg = cross_validate_xg(data_train)

# %%
df_cross_val_xg = pd.DataFrame.from_dict(cross_val_xg, orient='index')
df_cross_val_xg.rename(columns={0: "f1_score"}, inplace=True)
df_cross_val_xg.sort_values(by=["f1_score"], ascending=[False], inplace=True)
df_cross_val_xg
# Out:
#                                             f1_score
# df_modifiedOutlier_encoded_minmaxScaled     0.883787
# df_modifiedOutlier_encoded_                 0.872604
# df_encoded_minmaxScaled                     0.871642
# df_DF_encoded_minmaxScaled                  0.863388
# df_encoded_                                 0.862640
# df_deleteOutlier_encoded_minmaxScaled       0.861876
# df_deleteOutlier_encoded_                   0.856082
# df_DF_encoded_                              0.856079
# df_DF_modifiedOutlier_encoded_              0.853513
# df_DF_encoded_stdScaled_rounded             0.845656
# df_DF_deleteOutlier_encoded_minmaxScaled    0.838432
# df_DF_modifiedOutlier_encoded_minmaxScaled  0.837551
# df_DF_deleteOutlier_encoded_                0.835946
