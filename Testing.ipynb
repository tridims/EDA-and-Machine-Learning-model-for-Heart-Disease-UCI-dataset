# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./Dataset/heart_encode_scaled.csv')

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS  RestingECG  \
# count  734.000000  734.000000   734.000000  734.000000  734.000000
# mean     0.508730    0.380361     0.484929    0.164850    0.466621
# std      0.193440    0.160706     0.158739    0.371298    0.316513
# min      0.000000    0.000000     0.000000    0.000000    0.000000
# 25%      0.367347    0.259259     0.378882    0.000000    0.500000
# 50%      0.530612    0.351852     0.468944    0.000000    0.500000
# 75%      0.632653    0.444444     0.586957    0.000000    0.500000
# max      1.000000    1.000000     1.000000    1.000000    1.000000
#
#             MaxHR  ExerciseAngina     Oldpeak    ST_Slope  HeartDisease  \
# count  734.000000      734.000000  734.000000  734.000000    734.000000
# mean     0.528704        0.386921    0.146216    0.706403      0.476839
# std      0.187110        0.487377    0.173779    0.298884      0.499804
# min      0.000000        0.000000    0.000000    0.000000      0.000000
# ...
